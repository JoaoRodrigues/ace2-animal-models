# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="white")

# %%
df = pd.read_csv('agg_hs.csv', index_col='species')
df[df > 10] = 10.0
# df = df.apply(np.log2)
df.head()
# Out:
#                            B21       B22        B23        B24        B25  \
# species
# anas_platyrhynchos  -14.627005   0.00000 -21.316439 -28.579942 -26.093619
# bos_taurus          -15.474664   0.00000 -29.714244 -32.283842 -27.481347
# camelus_dromedarius -15.431256 -37.74682 -31.665059 -32.084747 -25.863790
# canis_lupus           0.000000   0.00000 -21.522350 -27.274141 -31.217614
# capra_hircus        -14.004472   0.00000 -26.691529 -29.547473 -25.249416
#
#                            B26        B27        B28        B29        B30  \
# species
# anas_platyrhynchos  -35.662383 -32.860751 -33.116269 -31.637944 -24.787504
# bos_taurus          -37.015567 -29.571559 -36.982647 -32.650702 -44.458940
# camelus_dromedarius -36.624608 -31.004475 -37.058202 -31.180240 -47.464224
# canis_lupus         -53.793558 -28.770439 -38.474092 -32.468314 -37.730826
# capra_hircus        -33.434980 -30.052277 -35.620993 -31.590276 -49.040092
#
# ...

# %%
ace2_cols = [c for c in df.columns if 'B' in c]
ace2 = df[ace2_cols]
vrbd_cols = [c for c in df.columns if 'E' in c]
vrbd = df[vrbd_cols]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
mask = ace2[ace2 == 0.0].astype(bool)
sns.heatmap(
    ax=ax,
    data=ace2[mask],
    linewidths=.5,
    cmap="RdBu_r",
    xticklabels=1,
    yticklabels=1,
    cbar_kws={'label': 'Residue Interaction Energy (a.u.)'}
)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
mask = vrbd[vrbd == 0.0].astype(bool)
sns.heatmap(
    ax=ax,
    data=vrbd[mask],
    linewidths=.5,
    cmap="RdBu_r",
    xticklabels=1,
    yticklabels=1,
    cbar_kws={'label': 'Residue Interaction Energy (a.u.)'}
)

# %%
# Normalize by human structure
nACE2 = ace2 - ace2.mean()
fig, ax = plt.subplots(figsize=(11, 9))
mask = ace2[ace2 == 0.0].astype(bool)
sns.heatmap(
    ax=ax,
    data=nACE2[mask],
    linewidths=.5,
    cmap="RdBu",
    xticklabels=1,
    yticklabels=1,
    cbar_kws={'label': 'Residue Interaction Energy (a.u.)'}
)

# %%
# Normalize by human structure
nVRBD = vrbd - vrbd.loc['homo_sapiens']
fig, ax = plt.subplots(figsize=(11, 9))
mask = vrbd[vrbd == 0.0].astype(bool)
sns.heatmap(
    ax=ax,
    data=nVRBD[mask],
    linewidths=.5,
    cmap="RdBu",
    xticklabels=1,
    yticklabels=1,
    cbar_kws={'label': 'Residue Interaction Energy (a.u.)'}
)
